# %%
url="https://drive.google.com/file/d/1NzPljKM7uDBp9P1GR4rpL4-kp7hsn-ol/view?usp=sharing"

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\namit\anaconda3\envs\cancer\python.exe

# %%
type(url)
