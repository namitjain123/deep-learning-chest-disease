# %%
import os
os.environ["MLFLOW_TRACKING_URI"] = "https://dagshub.com/namitjain123/deep-learning-chest-disease.mlflow"
os.environ["MLFLOW_TRACKING_USERNAME"] = "namitjain123"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "e54ede2db2747348031ce2a5b0d0d2dd7a4d8b5d"   # generate in Settings → Tokens

# %%
from src.cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
from src.cnnClassifier.utils.common import read_yaml, create_directories, save_json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
#       2 from src.cnnClassifier.utils.common import read_yaml, create_directories, save_json
#
# ModuleNotFoundError: No module named 'src'
